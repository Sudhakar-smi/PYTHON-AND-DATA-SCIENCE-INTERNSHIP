# %%
# 1) Write a python program that takes in a student name, class. It should also take in five subject marks of the students and find the total mark and percentage. Display a result in such a way that their name, class,  and percentage are printed.

name  = input("Enter student name: ")
s_class = input("Enter class:")

m1 = float(input("Enter marks of Subj 1: "))
m2 = float(input("Enter marks of Subj 2: "))
m3 = float(input("Enter marks of Subj 3: "))
m4 = float(input("Enter marks of Subj 4: "))
m5 = float(input("Enter marks of Subj 5: "))

total = m1 + m2 + m3 + m4 + m5 

percentage = (total / 500) * 100

print("Student Name :", name)
print("Class :",s_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
# Out:
# Student Name : Shekhar Saini
# Class : 2nd
# Total Marks : 275.0
# Percentage : 55.00000000000001 %

# %%
#2) Input 2 strings concatinate them and store in another variable. then perform generally used string methods on it like lower(), upper(), title(), swapcase(), capitalize(), casefold(), center(), count(), endswith(), find(), isalnum(), isdigit(), isnumeric(), isspace(), replace()


s1 = input("Enter first string: ")
s2 = input("Enter second string: ")


result = s1 + " " + s2
print("Concatenated String :", result)


print("lower():", result.lower())
print("upper():", result.upper())
print("title():", result.title())
print("swapcase():", result.swapcase())
print("capitalize():", result.capitalize())
print("casefold():", result.casefold())
print("center():", result.center(50, '*'))

print("count('a'):", result.count('a'))
print("endswith('a'):", result.endswith('a'))
print("find('a'):", result.find('a'))

print("isalnum():", result.isalnum())
print("isdigit():", result.isdigit())
print("isnumeric():", result.isnumeric())
print("isspace():", result.isspace())
# Out:
# Concatenated String : sonam bhurani
# lower(): sonam bhurani
# upper(): SONAM BHURANI
# title(): Sonam Bhurani
# swapcase(): SONAM BHURANI
# capitalize(): Sonam bhurani
# casefold(): sonam bhurani
# center(): ******************sonam bhurani*******************
# count('a'): 2
# endswith('a'): False
# find('a'): 3
# isalnum(): False
# isdigit(): False
# isnumeric(): False
# isspace(): False

# %%
# 3) Do practise of assignment operators
 

a = 10
b = 5

print("Initial value of a :", a)

a += b
print("After a += b :", a)

a -= b
print("After a -= b :", a)

a *= b
print("After a *= b :", a)

a /= b
print("After a /= b :", a)

a %= b
print("After a %= b :", a)

a **= b
print("After a **= b :", a)

a //= b
print("After a //= b :", a)
# Out:
# Initial value of a : 10
# After a += b : 15
# After a -= b : 10
# After a *= b : 50
# After a /= b : 10.0
# After a %= b : 0.0
# After a **= b : 0.0
# After a //= b : 0.0

# %%
# 4) In your last program where you find the total and percentage of a student's marks of 5 subject, find the grade of the student using conditional statement. Eg. grade 'A' if percentage is greator than or equals to 60, 'B' for  percentage is greator than or equals to 50 and less than 60,  'C' for  percentage is greator than or equals to 40 and less than 50,  'D' for  percentage is greator than or equals to 33 and less than 40, otherwise 'Fail'



name = input("Enter student name: ")
s_class = input("Enter class: ")

m1 = float(input("Enter marks of Subj 1: "))
m2 = float(input("Enter marks of Subj 2: "))
m3 = float(input("Enter marks of Subj 3: "))
m4 = float(input("Enter marks of Subj 4: "))
m5 = float(input("Enter marks of Subj 5: "))


total = m1 + m2 + m3 + m4 + m5
percentage = (total / 500) * 100


if percentage >= 60:
    grade = 'A'
elif percentage >= 50 and percentage < 60:
    grade = 'B'
elif percentage >= 40 and percentage < 50:
    grade = 'C'
elif percentage >= 33 and percentage < 40:
    grade = 'D'
else:
    grade = 'Fail'


print("Student Name:", name)
print("Class:", s_class)
print("Total Marks:", total)
print("Percentage:", percentage, "%")
print("Grade:", grade)
# Out:
# Student Name: Sumit Ranjan
# Class: 3rd
# Total Marks: 332.0
# Percentage: 66.4 %
# Grade: A
