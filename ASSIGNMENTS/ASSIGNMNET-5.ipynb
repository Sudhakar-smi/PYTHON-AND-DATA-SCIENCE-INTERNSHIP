# %%
# 1) Study the open weather API show more data in your API calling program

import requests

def weather_data(city):
    url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid=1872bb02e30343d99ae9e210edf3ca4c&units=metric"

    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        print("City:", data["name"])
        print("Humidity:", data["main"]["humidity"])
        print("Temperature:", data["main"]["temp"])
        print("Feels Like:", data["main"]["feels_like"])
        print("Minimum Temperature:", data["main"]["temp_min"])
        print("Maximum Temperature:", data["main"]["temp_max"])

    except requests.exceptions.RequestException as e:
        print("Error:", e)
    except KeyError as e:
        print("Data not found:", e)

city = input("Enter city name: ")
weather_data(city)
# Out:
# City: Alwar
# Humidity: 12
# Temperature: 38.75
# Feels Like: 36.06
# Minimum Temperature: 38.75
# Maximum Temperature: 38.75

# %%
# 3) Search for more free API's generate your and call them to fetch data. Display some data in your program.

import requests

def news_data():
    url = "https://newsapi.org/v2/top-headlines?country=us&category=business&apiKey=7b505153182644b2890174f5fb86e976"

    try:
        response = requests.get(url)
        response.raise_for_status()
        data = response.json()

        print("Top Business News Headlines:\n")

        for article in data["articles"][:5]:

            print("Title:", article["title"])
            print("Author:", article["author"])
            print("Source:", article["source"]["name"])
            print("Published At:", article["publishedAt"])
            print("Description:", article["description"])
            print("-" * 60)

    except requests.exceptions.RequestException as e:
        print("Error:", e)

news_data()
# Out:
# Top Business News Headlines:
#
# Title: SpaceX, OpenAI and Anthropic IPOs set to test limits of AI boom - Financial Times
# Author: Ryan McMorrow, George Hammond
# Source: Financial Times
# Published At: 2026-05-23T08:00:06Z
# Description: Elon Musk, Sam Altman and Dario Amodei battle over who can command Wall Street’s deepest pools of capital
# ------------------------------------------------------------
# Title: Chrysler, Dodge, And Ram Have 9 New Models Coming By 2030. Here's All Of Them - Motor1.com
# Author: Jeff Perez
# Source: Motor1
# Published At: 2026-05-23T07:54:06Z
# Description: Stellantis has an entire range of new products coming to the US, including new Chrysler SUVs, small Ram trucks, and even possibly a halo SRT model from Dodge.
# ------------------------------------------------------------
# Title: Space Force awards Viasat, SES $437 million for military satellite network - SpaceNews
# Author: Sandra Erwin
# Source: SpaceNews
# Published At: 2026-05-22T23:27:58Z
# Description: Space Force awards Viasat, SES $437 million for military satellite network Space Force awards Viasat, SES $437 million for military satellite network
# ------------------------------------------------------------
# Title: E. coli outbreak linked to California restaurant chain sickens nine people across state - San Francisco Chronicle
# Author: Catherine Ho
# Source: San Francisco Chronicle
# Published At: 2026-05-22T22:39:45Z
# Description: State health officials linked the outbreak to ground beef kebabs from the Kebab Shop, a restaurant chain with nine locations in the Bay Area.
# ------------------------------------------------------------
# Title: 'I got drafted': Inside Meta's push to move 7,000 staff into its AI task force - Business Insider
# Author: Hugh Langley, Charles Rollet
# Source: Business Insider
# Published At: 2026-05-22T21:46:00Z
# Description: Meta reassigned thousands of employees to a new AI task force during this week's layoffs. Some are anxious and confused about what comes next.
# ------------------------------------------------------------

# %%
import random
low=0
high=100
gues=0
random.randint
number=random.randint(low,high)
while True:
    guess=int(input(f"enter a number between({low}-{high}):"))
    gues+=1
    if(guess<number):
        print(f"{guess}is too low")
    elif(guess>number):
        print(f"{guess} is too high")
    else:
        print(f"{guess} is correct")
        break
    print(f"this round takes you{gues} guesss")
# Out:
# 33is too low
# this round takes you1 guesss
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       4 gues=0
#       5 random.randint
#       6 number=random.randint(low,high)
#       7 while True:
# ----> 8     guess=int(input(f"enter a number between({low}-{high}):"))
#       9     gues+=1
#      10     if(guess<number):
#      11         print(f"{guess}is too low")
#
# ValueError: invalid literal for int() with base 10: 'guess'
